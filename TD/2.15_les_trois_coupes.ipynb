# %% [markdown]
# # Les trois coupes DMOJ coci06c5p1 ⭐

# %% [markdown]
# ### Tâche à réaliser 🎯
#
# Jaloux de la position de Mirko en tant que chef du village, Borko a fait irruption dans sa tente et a tenté de démontrer l'incompétence de Mirko à diriger par un tour.
#
# Borko place trois gobelets opaques sur la table, l'un à côté de l'autre (ouverture vers le bas) et une petite balle sous le gobelet le plus à gauche. Il échange ensuite plusieurs fois deux gobelets de l'une des trois manières possibles. Mirko doit dire sous quel gobelet la balle se retrouve.
#
# Le sage Mirko sourit, les bras croisés, tandis que Borko s'efforce de déplacer les gobelets de plus en plus vite. Ce que Borko ne sait pas, c'est que des programmeurs à l'arrière enregistrent tous ses mouvements et utiliseront un simple programme pour déterminer où se trouve la balle.
#
# Ce programmeur c'est vous!
#
# ### Entrée 🔠
#
# La première et unique ligne contient une chaîne de 50 caractères au maximum, les coups de Borko. Chacun des mouvenements est représenté par un caractère A, B ou C.
#
# ### Sortie 🖥️
# Donne l'indice du gobelet sous lequel se trouve la balle : si elle est sous le gobelet de gauche, si elle est sous le gobelet du milieu ou si elle est sous le gobelet de droite.
#
# ### Exemples 👀
#
# Entrée: AB
#
# > Sortie: "La balle est sous le gobelet de droite"
#
# Entrée: CBABCACCC
#
# > Sortie: "La balle est sous le gobelet de gauche"

# %% [markdown]
# ## Votre solution :

# %%
entry = "CBABCACCC"
MAX_CHARACTERS_PERMITTED = 50;

if (len(entry) > MAX_CHARACTERS_PERMITTED or len(entry) < 1):
    raise Exception('Une erreur est survenue lors de la saisie de caractères')

tab_pos = [1, 0, 0]

for c in entry:
    if (c == 'A'):
        tab_pos[0], tab_pos[1] = tab_pos[1], tab_pos[0]
    elif (c == 'B'):
        tab_pos[1], tab_pos[2] = tab_pos[2], tab_pos[1]
    elif (c == 'C'):
        tab_pos[0], tab_pos[2] = tab_pos[2], tab_pos[0]
    else:
        raise Exception('Votre entrée comporte un format de données non valide')
    
if (tab_pos[0] == 1):
    print('La balle est à gauche')
elif (tab_pos[1] == 1):
    print('La balle est au milieu')
else:
    print('La balle est à droite')
# Out:
# La balle est à gauche

# %% [markdown]
# ## [Home](0_Index.ipynb)🏠
# ![licence.png](pics/licence.png) Licence Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International
