# %% [markdown]
# # Divisible ⭐

# %% [markdown]
# ### Tâche à réaliser 🎯
#
# Ecrire un algorithme, avec des structures conditionnelles sans opérateurs logiques, qui retourne une valeur booléenne indiquant si deux nombres sont divisibles l’un par l'autre.
#
# Indications :
# - Les valeurs saisies pour les nombres a et b sont des entiers non nuls, mais pas forcément positifs.
# - En Python,  % correspond au modulo. Par exemple  c= a % b affecte à c le reste de la division euclidienne de a par b.
#
#
# ### Entrée 🔠
# 2 entiers non nuls
#
# ### Sortie 🖥️
# Une valeur booléenne
#
# ### Exemples 👀
# Entrée : a=10 et b=30
# > Sortie : True
#
# Entrée : a=30 et b=-10
# > Sortie : True
#
# Entrée : a=-10 et b=-30
# > Sortie : True
#
# Entrée : a=8 et b=12
# > Sortie : False

# %% [markdown]
# ## Votre solution :

# %%
a = int(input("Veuillez entrer la valeur de a : "))
b = int(input("Veuillez entrer la valeur de b : "))

if (a == b and a == 0):
    print("LES NOMBRES NE PEUVENT ÊTRE NULS !")
else:
    print(a % b == 0 or b % a == 0)
# Out:
# Veuillez entrer la valeur de a : -10
# Veuillez entrer la valeur de b : 520
# True

# %% [markdown]
# ## [Home](0_Index.ipynb)🏠
# ![licence.png](pics/licence.png) Licence Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International
