# %% [markdown]
# # Table de multiplication 3 ⭐

# %% [markdown]
# ### Tâche à réaliser 🎯
#
# Écrire une fonction prenant en entrée 4 paramètres `Basedeb, BaseFin, ValDeb` et `ValFin`.
# Cette fonction affiche toutes les tables de multiplication pour les bases et les valeurs comprises dans les intervalles fournis en paramètre.
#
# ### Entrée 🔠
#
# `Basedeb, BaseFin, ValDeb` et `ValFin`
#
# ### Sortie 🖥️
# Les tables de multiplication
#
# ### Exemples 👀
#
# Multiplication(1,4,0,3)
#
# > Sortie:
# 1 * 0 = 0
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 2 * 0 = 0
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 3 * 0 = 0
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 4 * 0 = 0
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12

# %% [markdown]
# ## Votre solution :

# %%
def Multiplication(Basedeb: int, BaseFin: int, ValDeb: int, ValFin: int):
    for i in range(Basedeb, BaseFin + 1):
        for j in range(ValDeb, ValFin + 1):
            res = i * j
            print(f"{i} * {j} = {res}")

Multiplication(1,4,0,3)
# Out:
# 1 * 0 = 0
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 2 * 0 = 0
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 3 * 0 = 0
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 4 * 0 = 0
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12

# %% [markdown]
# ## [Home](0_Index.ipynb)🏠
# ![licence.png](pics/licence.png) Licence Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International
